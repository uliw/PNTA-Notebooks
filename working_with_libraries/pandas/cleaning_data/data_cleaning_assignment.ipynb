# %% [markdown]
# ### Assignment

# %% [markdown]
# Learning Outcomes:
#
# 1.  Filter datasets by dropping rows with missing values (`NaN`).
# 2.  Sort datasets based on a specific column in ascending or descending order.
# 3.  Group data by a column and compute aggregate statistics.
# 4.  working with date-time data

# %% [markdown]
# ### 1.  Dropping empty cells (2 points)

# %% [markdown]
# Write a Python script that:
#
# 1.  Imports the volcano dataset from `volcanoes.csv` as a Pandas DataFrame.
# 2.  Finds and drops all rows where the "DEATHS" column has missing values (`NaN`).
# 3.  Use the `head()` method to print and compare the original DataFrame and the cleaned-up DataFrame.

# %%
#

# %% [markdown]
# ### 2.  Sorting (2 points)

# %% [markdown]
# In this part of the exercise, you will learn how to sort the volcano dataset by the number of deaths in **decreasing** order. Sorting data is useful for identifying trends or ranking entries based on importance. For instance, by sorting the data on the "DEATHS" column, you can quickly identify the most devastating volcanic eruptions.

# %%
#

# %% [markdown]
# ### 3.  Grouping and subtotals (6 points)

# %% [markdown]
# 1.  Load the `volcanoes.csv` dataset as a Pandas DataFrame.
# 2.  Group the DataFrame by the "Country" column and calculate the total number of deaths for each country.
# 3.  Sort the grouped data by the number of deaths (in descending order), so that the countries with the most deaths appear first.
# 4.  Print the resulting DataFrame or Series to review the totals for each country.
# 5.  **Note:** The output of the `group_by` method is a `DataSeries`, not a `DataFrame`.  So lookup how to sort a `DataSeries`
#
# **You** can break this into three steps:
#
# -   Use `groupby()` to group the data by "Country".
# -   Use `sum()` to calculate totals for the "DEATHS" column.
# -   Use `sort_values(ascending=False)` to sort the totals in descending order.
# -   Apply this approach to the "Country" and "DEATHS" columns in the volcano dataset to complete the task.

# %%
#

# %% [markdown]
# ### 4.  Pandas and Date-Time Data (4 points)

# %% [markdown]
# The file `beckley_airport.csv` contains a few hours of climate data from an airport in West Virginia.
#
# -   Import the data, and convert the "DATE" column into a correctly parsed `datetime_column`
# -   add a column with the date-time in seconds.
# -   get the first and last values in seconds, and calculate the length of the climate record in hours.

# %%
#

# %% [markdown]
# ### 5.  Advanced Problem set: Categorizing Date time data (6 points)

# %% [markdown]
# 1.  Use the `beckley_airport.csv` data-file, and categorize the data into day and night.
# 2.  In a second step modify the `categorize_time` function in such a way that it returns `day_1`, `day_2` etc (and similar for the nights). For this, you need to loop over all `date_time` entries and then use a counter that only increments when your measurement's reach a new day (or night). Start by implementing the solution from the previous task as a loop. Once this works start modifying the function.
# 3.  Calculate and print the average day and night time temperatures using the pandas `group_by` functions.

# %%
#

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `A#-assignment-name-firstname-lastname`
#
# -   Where `A#` is something like A1, A2 A3, etc.
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook). This can be shortened as long as it remains clear which assignment it is.
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images, or external data, you must also copy the image and data files!
# Your notebook/pdf must start with the following lines :
#
# **ESS245: Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   Re-read the learning outcomes and verify that you are comfortable with each concept. If not, please speak up on the discussion board and ask for further clarification. I can guarantee that if you feel uncertain about a concept, at least half the class will be in the same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook format **and**
# `pdf` format:
#
# -   **Do not use File -> Save and Export as -> pdf!!!**
# -   You **must** use your **browser's print function** (`Ctrl-P`, or `Cmd-P` on a Mac) and then select `Save as pdf`.  In the past, this worked best with Chrome or Firefox.
#
# Please submit **both files** on Quercus. Note that the pdf export can fail if your file contains invalid markup/python code. So you need to check that the pdf export is complete and does not miss any sections. If you have export problems, don't hesitate to contact the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter python code. Please use the respective cell below each question, or create a python cell where necessary. Add text cells to enter your answers where appropriate. Your responses will only count if the code executes without error. It is thus recommended to run your solutions before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by** hand. Instead, write code that produces the answer. Your pdf file\* should show the code and the results of the code execution.\*
