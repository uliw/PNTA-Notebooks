# %% [markdown]
# ## Block Statements Assignment 1

# %% [markdown]
# 1.  All questions should be solved with loop and if statements,
#     counters, and range expressions
# 2.  In order to answer these questions, add a code boxes after each question, so that the TA can see the question, and how you solved it.
# 3.  Run your code and make sure it actually produces the requested result!
# 4.  Remember that variables which you are using to count or to create
#     sums, have to be initialized to zero before using them.
# 5.  Marking scheme per question:
#     -   2 pts if the code produces the requested output, unless otherwise noted

# %% [markdown]
# ### If statements (10 pts)

# %% [markdown]
# 1.  If you were to execute this code block, what result would you get? Please
#     think it through rather than running the code! and add the result in a text
#     cell below (4 pts):
#
#         a = 5
#
#         if (a == 5) :
#            print(f"a equals five")
#         if a > 3 :
#            print(f"a is larger than three")
#         if a < 5 :
#            print(f"a is smaller than five")
#         if a < 10:
#         	print(f"a is smaller than 10")
#
# 2 . [@2] How would you need to restructure the above code so that it only prints
#     the result of the first true comparison? Write your code below and test it
#     with `a=3` and `a=9`.  Note, you must keep all comparisons in the code!  This
#     time, your answer should be python code that executes without errors and
#     produces the required results (2 pts).
#
# 1.  [@] Use the following dictionary that shows Bob's grades in his two courses:

# %%
d = {"Bob": [50, 50]}

# %% [markdown]
# Add code that determines if Bob failed his first year or not. The condition to
# pass his first year is that he achieves at least a 50 in at least one
# course. Test your code with the following values for Bob's grade: `[50,50]`,
# `[40,50]`, `[50,40]`, and `[40,40]`. (4 pts)

# %% [markdown]
# ### Loops  26 pts

# %% [markdown]
# #### Using loops to display elements in a list

# %% [markdown]
# Last but not least, execute the following statements so that these
# variables become known to your jupyter session

# %%
my_text = "This is just some random text"
my_numbers = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 1.  Write a loop statement which display all elements of `my_numbers`
#     (i.e., one element per line).
#     1.  Write a loop statement which displays all elements of `my_text` in
#         reverse. You should use a range expression in the for statement.
#     2.  Write a loop statement which displays every third element of
#         `my_text` You should use a range expression in the for statement.

# %% [markdown]
# #### Using loops to count elements in a list

# %% [markdown]
# 4.  Write a loop statement which counts the number of all elements in
#     `my_numbers`

# %% [markdown]
# #### Using loops to calculate the sum of all elements in a list

# %% [markdown]
# 5.  Write a loop statement which calculates the sum of all elements
#     in `my_numbers`

# %% [markdown]
# #### Combining loop and if statements

# %% [markdown]
# 6.  Write a loop statement which counts the number of all
#     elements in `my_numbers` which are equal to 3
#     1.  Write a loop statement which counts the number of all elements in
#         `my_text` which are equal to "s"
#     2.  Write a loop statement which counts the number of all elements in
#         `my_text` which are not "a"
#         1.  Write a loop statement which calculates the sum of all elements
#             in `my_numbers` which are equal to 3
#     3.  Write a loop statement which calculates the sum of all elements
#         in `my_numbers` which are smaller or equal to 6 and larger than 2
#     4.  Write a loop statement which displays every third element of
#         `my_nymbers` and the element which follows every 3<sup>rd</sup> element. For
#         this, you will need a counter, and access the elements of
#         `my_numbers` by combining an index expression with an
#         if-statement (checkout your list module if in doubt). Your Output
#         should look like this:
#
#     3, 2
#     9, 2
#     12, 1 etc.
#
# 11. Write a loop statement which tests whether a given element of  `my_list` is a binary number or not. Your printout should look like this:
#
#     010011 is a binary number
#     2012 is not a binary number

# %%
my_list  = ["0101011", "0102011", "ab102011"]

# %% [markdown]
# #### Using a loop to modify a list

# %% [markdown]
# 12. Make a copy of `my_numbers` , and write some python code that  replaces each occurrence of 3 in `my_numbers` by its square (9).
#     13. Use the below dictionary and write a for loop that lists
#         all minerals that contain sulfate. At the end of the loop,
#         print the total number of minerals in the dictionary, and the number of minerals
#         that contain sulfate. Your output should look, e.g., like this:
#
#     Barite: BaSO4
#     Anhydrite: CaSO4
#     Gypsum: CaSO4 x H2O
#     Found 3 sulfate bearing minerals out of 5 in dictionary

# %%
d :dict = {"Barite": "BaSO4",
           "Anhydrite": "CaSO4",
           "Gypsum": "CaSO4 x H2O",
           "Pyrite": "FeS2",
           "Quartz": "SiO2",
           }
