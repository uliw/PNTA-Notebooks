# %% [markdown]
# ## Loop Statements Assignment

# %% [markdown]
# Copy this notebook to your submissions folder before editing
# it.
#
# 1.  Solve all questions with loop and/or if statements. Use counters and
#     range expressions where appropriate.
# 2.  Where necessary, add a code box after each question.
# 3.  Run your code and make sure it produces the requested result!
# 4.  Remember to initialize counters before using them.

# %% [markdown]
# ### Learning outcomes

# %% [markdown]
# -   become comfortable using loop statements
# -   learn how to use loops to iterate various data types
# -   learn how to create and use counters
# -   learn how to combine counters, comparisons and if statements with
#     loops to selectively process list-type data
# -   Understand how loops change variable values during execution and how you can leverage this to execute more complex code
# -   Get started with type hints

# %% [markdown]
# ### Using loops to display elements in a list

# %% [markdown]
# 1.  Write a loop statement that displays all elements of the list below

# %%
l :list = "This is just some random text".split()

# %% [markdown]
# Note the use of `:list`. These are so-called type hints. Type hints are
# ignored by python but are a concise way to document your code. We
# will slowly start using them.
#
# 2.  Write a loop statement that displays all elements of
#     `my_text` in reverse without using the `range()` function

# %%
my_text :str = "This is just some random text"

# %% [markdown]
# 3.  Write a loop statement that displays every third element of
#     `my_text` Use a slice expression in the for statement.

# %%
my_text :str = "This is just some random text"

# %% [markdown]
# ### Using loops to count elements in a list

# %% [markdown]
# 4.  Write a loop statement that counts the number of elements in
#     `my_numbers`

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# ### Using loops to calculate the sum of all elements in a list

# %% [markdown]
# Use one code cell per question:
#
# 5.  Write a loop statement that calculates the sum of all numbers
#     in `my_numbers`

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 6.  Write a loop statement that calculates the running total of all
#     elements in `my_numbers` (see the example output below).

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
#     i = 0, value = 1, running total = 1
#     i = 1, value = 6, running total = 7
#
# 7.  Use a for loop with a slice to print the square of all
#     even numbers from 0 to 10 (this includes 0 and 10!)

# %% [markdown]
# ### Combining loop and if statements

# %% [markdown]
# Use one code cell per question:
#
# 8.  Write a loop statement that counts the number of all
#     elements in `my_numbers` which are equal to 3

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 9.  Write a loop statement that counts the number of all elements in
#     `my_text` which are equal to "s"

# %%
my_text :str = "This is just some random text"

# %% [markdown]
# 10. Write a loop statement that counts the number of all elements in
#     `my_text` which are not "a"

# %%
my_text :str = "This is just some random text"

# %% [markdown]
# 11. Write a loop statement that counts the number of all elements in
#     `my_numbers` that are equal or smaller than 12

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 12. Write a loop statement that calculates the sum of all elements
#     in `my_numbers` that are equal to 3. In other words, you need to
#     calculate the total value of all numbers in `my_numbers` that
#     are equal to 3. If this is unclear, please ask for
#     clarification.

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 13. Write a loop statement that calculates the sum of all elements
#     in `my_numbers` that are either smaller than 3 or larger than 5

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 14. Write a loop statement that calculates the sum of all elements
#     in `my_numbers` which are larger or equal to 6

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 15. Write a loop statement that displays every third element of
#     `my_numbers` and the element which follows every 3<sup>rd</sup> element. Use the enumerate function and slicing syntax to achieve this.

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# your output should look like this
#
#     3, 2
#     9, 2
#     12, 1 etc.
#
# 16. As before, but this time you are not allowed to use slicing
#     syntax or the range function(). Rather, use a counter and if statement inside your loop to achieve the same output.

# %%
my_numbers :list = [1, 6, 3, 2, 7, 9, 2, 3, 12, 1, 2, 3, 6, 5, 6, 7]

# %% [markdown]
# 17. Write a loop statement that tests whether `s1` contains a
#     binary number or not. The idea being that you test each element
#     of the string. Test your code with `s2`

# %%
s1 :str = "0101011"
s2 :str = "0102011"

# %% [markdown]
# 18. Use the below dictionary and write a for loop that lists
#     all minerals that contain sulfate. At the end of the loop,
#     print the total number of minerals in the dictionary, and the number of minerals
#     that contain sulfate. Your output should look, e.g., like this:
#
#     Barite: BaSO4
#     Anhydrite: CaSO4
#     Gypsum: CaSO4 x H2O
#     Found 3 sulfate bearing minerals out of 5 in dictionary

# %%
d :dict = {"Barite": "BaSO4",
           "Anhydrite": "CaSO4",
           "Gypsum": "CaSO4 x H2O",
           "Pyrite": "FeS2",
           "Quartz": "SiO2",
           }

# %% [markdown]
# #### Advanced Question 1

# %% [markdown]
# You have a warehouse full of core samples of variable
# length. You know the number of core-samples and their length, and you know that each centimeter of core weighs 645 grams.
# You need to determine how many samples you can load into your minivan
# before you exceed the vans load limit.
#
# There are various ways to solve this, but here, I want you to
# solve this with a while loop. The loop should iterate over each sample
# in the list, calculate it's weight, and add it to the running weight. Once
# the running weight exceeds the load limit. Your code should output something like
#
#     You can load the first X samples
#     Your final weight will be X kg
#
# Use the following boundary conditions:

# %%
weight_per_centimeter :int = 645 # gram
sample_length :list = [14, 1, 14, 18, 21, 10, 27, 28, 27, 7, 19, 26, 28, 18, 25, 24, 15, 13, 30, 21]
load_limit : int = 190 # kg

# %% [markdown]
# Notes and pointers for this question:
#
# -   The above is straightforward in principle, but, in reality, it is a  real mind-bender.
# -   Use print statements inside the loop to track what your loop is doing.
# -   You will likely need to use the `break()` statement.
# -   Increase the load limit to 300 kg to test if your code handles the
#     case that you can load more samples than are in the list.
# -   If you need more than one hour for this question, please move on. I
#     do not expect that everyone will be able to answer this question.

# %% [markdown]
# ### Advanced Question 2

# %% [markdown]
# In the following, you are tasked to print the following dictionary as a markdown table:

# %%
d = {
    "col1": {
        "header": "CO_2",
        "values": [280, 300, 410],
    },
    "col2": {
        "header": "Temp",
        "values": [18, 19, 20],
    },
}

# %% [markdown]
# Markdown tables are defined in the following way:
#
#     |     CO2 |    Temp |
#     | ------- | ------- |
#     |     280 |      18 |
#     |     300 |      19 |
#     |     410 |      20 |
#
# Pointers:
#
# -   you cannot assume that you know how many rows and columns are in `d`
# -   the task is simple but requires many of the skills you learned in the last month. Use your notes/textbook! It also  involves a lot of steps. So it is best to write down each step and find out how to solve each step, before trying to solve the entire task. If need, be, break it down further. To give and example:
#     1.  Find out how many columns are in `d`
#     2.  Print column headers
#     3.  etc. etc.
# -   Since we want the output rendered as markdown, you cannot use the print statement. Rather, build a single string that contains everything (including the linefeeds!). The following template shows you how to tell your notebook to interpret your output as markdown syntax:

# %%
# import some markdown magic
from IPython.display import display_markdown

# This string variable will hold your ouput
output = ""


# tell your notebook to treat the output like a markdown cell
display_markdown(output)
# This will show the contents of the string.
# print(output)

# %% [markdown]
# ### Marking scheme:

# %% [markdown]
# -   1 pt if the code produces the requested output
#     -   1 pt if the code is as requested
#     -   Total: 36 plus 8 for the advanced question (4 pts for the correct weight and number of samples, 2 pts for correct loop setup, 2 pts for correct use of the `break` statement)

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `assignment-name-firstname-lastname`
#
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook)
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images, you must also copy the image files!
#
# Your notebook/pdf must start with the following lines :
#
# **ESS245: Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   Re-read the learning outcomes and verify that you are comfortable
#     with each concept. If not, please speak up on the discussion board
#     and ask for further clarification. I can guarantee that if you feel
#     uncertain about a concept, at least half the class will be in the
#     same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook
# format **and** `pdf` format. **To export your notebook as pdf
# use your browser's print function (`Ctrl-P`) and then select**
# `Save as pdf`.  In the past, this worked best with Chrome or Firefox.
#
#  Please submit **both files** on Quercus. Note that the pdf
# export can fail if your file contains invalid markup/python code. So
# you need to check that the pdf export is complete and does not miss
# any sections. If you have export problems, don't hesitate to contact
# the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter
# python code. Please use the respective cell below each question, or
# create a python cell where necessary. Add text cells to enter your
# answers where appropriate. Your responses will only count if the code
# executes without error. It is thus recommended to run your solutions
# before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by**
# **hand. Instead, write code that produces the answer. Your pdf file**
# **should show the code and the results of the code execution.**
