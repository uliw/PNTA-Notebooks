# %% [markdown]
# ## Assignment

# %% [markdown]
# As usual, copy this notebook to your private directory, and add your personal header before working through this assignment.

# %% [markdown]
# ### Learning outcomes

# %% [markdown]
# -   Know how to query object methods
# -   Understand the difference between object methods and functions
# -   Understand the difference between methods that operate **IN PLACE** and functions that return a modified copy
#     of an object

# %% [markdown]
# ### Questions 38 points

# %% [markdown]
# Execute the following block so that `my_list` becomes known in your local Jupyter session.

# %%
my_list = [3, 4, 5, 12, 0, 11, 1, 2, 9, 8, 7, 13, 10]

# %% [markdown]
# **Please answer each question with a code cell immediately below the question**
#
# 1.  Add a text block below this paragraph and list all user-visible methods of the `my_list` object that have the **IN PLACE** warning in their help text (if in doubt, consult your working with lists module on how to find out about this). There is no need to add a code cell; just list what you find (3 points).
#
# 2.  Add a code block that will create a sorted copy of `my_list` using a Python function (as opposed to a list method). Print the list to verify that it has been sorted (4 points).
#
# 3.  Add code below that returns a sorted copy (not reference) of `my_list`, but this time use list method(s) rather than a function (4 points).

# %%
my_list = [3, 4, 5, 12, 0, 11, 1, 2, 9, 8, 7, 13, 10]

# %% [markdown]
# 1.  [@] Add a code block below that displays `my_list` in reverse order without affecting the actual ordering of `my_list` (2 points). Add a second line that uses a list method to sort the contents of `my_list`. (2 points). Total: 4 points
#
# 2.  Execute the following statement, and add a Python statement that counts the occurrences of the number five in `long_list`. (1 pt)

# %%
long_list = [2, 2, 5, 5, 0, 3, 3, 4, 3, 2, 4, 2, 4, 3, 3, 4, 2, 1, 5,
             3, 0, 4, 4, 2, 4, 1, 1, 2, 1, 2, 0, 0, 0, 4, 2, 5, 5, 5, 0, 3, 4, 3,
             3, 5, 3, 5, 2, 1, 0, 3, 3, 3, 0, 2, 3, 5, 4, 4, 4, 1, 5, 5, 5, 3, 5,
             3, 0, 1, 1, 1, 4, 4, 0, 2, 2, 1, 4, 4, 3, 2, 0, 1, 1, 0, 3, 3, 0, 3,
             0, 3, 4, 2, 3, 0, 2, 3, 5, 0, 4, 5]

# %% [markdown]
# 6.  Write a Python statement that returns the position (index) of the first occurrence of the number three. 2 points
#
# 7.  Create a copy of `a` named `b` and reverse the copy, then print both variables (see below). Your results should look like the comment in the code box below. 2 points

# %%
a = [3, 4, 5, 12]
# print(a)
# print(b)
# should result in
# 3, 4, 5, 12
# 12, 5, 4, 3

# %% [markdown]
# 8.  Write a Python statement that adds (appends) the elements of `b` to `a` 2 points
#
# 9.  Write a statement that removes the second occurrence of the number twelve in `a` 2 points
#
# 10. Write a statement that uses a different method than in the previous question to remove the first occurrence of the number twelve in `a` 2 points
#
# 11. Write a statement that inserts the number twelve into `a` at the same position where you deleted it in the previous question. 2 points
#
# 12. Explain the difference between `extend()` and `append()` 4 points.
#
# 13. Explain in your own words what happens when you execute the following (4 points)

# %%
a = [1, 2, 3,]
a + 2 * a

# %% [markdown]
# 14. Write a Python statement that prints `a` in reverse order without using a list method or function. 2 points

# %% [markdown]
# ### Advanced questions (9 points)

# %% [markdown]
# ### A FIFO buffer (7 points)

# %% [markdown]
# In computing, one often needs a so-called buffer. This is a space where we, e.g., store measurement values from an analytical instrument. Often, the values arrive faster than we can process them, but then there is a pause. So we need to temporarily store the results in such a way that we can accommodate the first 10 values, but once the buffer is full, we start discarding the oldest data. This principle is called first in, first out (FIFO). Using only the **knowledge learned so far**, write a one-line statement that realizes the FIFO principle with a list: E.g.
#
#     a = [0, 0, 0, 0] # this is our empty buffer
#
#     12 is the first value arriving in the buffer, so it now reads
#     [12, 0, 0, 0] # note that the buffer length has not changed,
#     rather we deleted the right most element
#
#     -2 is next value arriving from our instrument, so now the buffer
#     looks like this
#     [-2, 12, 0, 0]
#
# Here is a code template. Add a one-line Python statement that removes the last list element, shifts all remaining list elements to the right, and adds the new value as the first element in the revised list so that the new buffer state is `[12, 0, 1, 3]`

# %%
a = [0, 1, 3, 4] # buffer of length 4
print(a)
v = 12 # new value arriving from analytical equipment

# add your one line statement below this comment

print(a) # verify your result

# %% [markdown]
# ### 2 Joining lists (4 points)

# %% [markdown]
# Consider the following two lists:

# %%
a = [1, 2, 3]
b = ['John', 'Anna', 'George']

# %% [markdown]
# Find a Python expression (aka function) that combines the two lists into a single list and prints the result as `[(1, 'John'), (2, 'Anna'), (3, 'George')]`. This is not in the textbook and requires that you do some sleuthing on your own with Google. I am looking for a one-liner solution involving no more than two Python function calls (excluding the print statement). Also, I am not looking for a manual solution where you split and combine each list element by element.
# Note do not spend more than 30 minutes on this task unless you have nothing else to do.
#
# A note on searching strategies: I would google like this: "Python stackoverflow how to combine two lists". If that results in too much information, try "Python for Dummies how to combine two lists". If all else fails, post on Piazza.
#
# **Hint** If your statement seems correct but does not print a list, Google how the statement has changed from Python 2.x to Python 3.x

# %% [markdown]
# ### Marking Scheme

# %% [markdown]
# Total points: 49

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy an existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `a#-assignment-name-firstname-lastname`
#
# -   Where `a#` is something like a1, a2 a3, etc.
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook). This can be shortened as long as it remains clear which assignment it is.
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images or external data, you must also copy the image and data files!
# Your notebook/pdf must start with the following lines :
#
# **ESS245: Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   Re-read the learning outcomes and verify that you are comfortable with each concept. If not, please speak up on the discussion board and ask for further clarification. I can guarantee that if you feel uncertain about a concept, at least half the class will be in the same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook format **and**
# `pdf` format:
#
# -   **Do not use File -> Save and Export as -> pdf**
# -   You **must** use your **browser's print function** (`Ctrl-P` or `Cmd-P` on a Mac) and then select `Save as pdf`.  In the past, this worked best with Chrome or Firefox.
#
# Please submit **both files** on Quercus. Note that the pdf export can fail if your file contains invalid Markup/Python code. So you need to check that the pdf export is complete and does not miss any sections. If you have export problems, don't hesitate to contact the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter Python code. Please use the respective cell below each question, or create a python cell where necessary. Add text cells to enter your answers where appropriate. Your responses will only count if the code executes without error. It is thus recommended to run your solutions before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by** hand. Instead, write code that produces the answer.
# Your pdf file **should show the code and the results of the code execution.**
