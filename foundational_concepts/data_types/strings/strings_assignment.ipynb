# %% [markdown]
# ### Assignment

# %% [markdown]
# #### Learning outcomes

# %% [markdown]
# -   get comfortable working with string methods
# -   get comfortable manipulating strings
# -   start to combine commands in creative ways
#
# As usual, copy this notebook, edit the title, add your student id, etc. here before starting to work on this assignment
#
# Use the following strings for all exercises unless noted otherwise:
#
#     s_1 = "This is the first string"
#     s_2 = "This is the second string"
#     s_3 = "just some random letters"
#     s_4 = "This is the first string with a comma on the end,"
#
# To solve the questions below, you need to use your knowledge about how to manipulate lists (i.e., ranges) and how to query the methods provided by a string object. For each of the following questions, please insert a new cell below each question. If necessary, review how to split an existing notebook cell and how to insert a new cell.
#
# Your code should first define all the variables used in the cell, then continue with the python statements to yield the required results.
# **Please answer each question with a code cell immediately below the question**
#
# 1.  Provide some code that adds a comma to the end of `s_1` (2 points)

# %%
#

# %% [markdown]
# 2.  Use slicing syntax to remove the comma at the end of `s_1` and `s_4`.
#     (2 points)

# %%
#

# %% [markdown]
# 3.  Provide a code example which combines `s_1`, `s_2`, and `s_3` into a new string `s_5` using the `+` operator (2 points)

# %%
#

# %% [markdown]
# 4.  Do the same, but this time make sure the resulting string has commas and blanks after each sub-string. Store the result in `s_6`. Your result should look like this example `"This is the first string, This is the second string, just some random letters"` (typing it does not count). (2 points)

# %%
#

# %% [markdown]
# 5.  Use a string-object method that will split `s_6` into 3 sub-strings (use the comma as a separator). Store the result in `x`. 2 points

# %%
#

# %% [markdown]
# 6.  Use the `type()` function to query the variable type of `x`, and `x[1]`. 2 points

# %%
#

# %% [markdown]
# 7.  Use a string method that replaces all "i" characters in `s_1` with "y" 2 points

# %%
#

# %% [markdown]
# 8.  Provide code that extracts the file name and the file-type extension from `my_excel_spreadsheet.xls` 2 points

# %%
#

# %% [markdown]
# 9.  Strip the 4 rightmost characters from `a = "123456"` Do not store the result. 2 points

# %%
#

# %% [markdown]
# 10. Strip the 4 leftmost characters from `a = "123456"` Do not store the result 2 points

# %%
#

# %% [markdown]
# 11. Typing a list containing strings is tedious, e.g., `a = ["g", "h", "e", "l"]`. Can you think of a way to create the same list with less typing? 2 points.

# %%
#

# %% [markdown]
# 12. Write a one-function statement that counts the numbers of characters, including blanks in `s_1` (do not use loops, etc.!). 2 points

# %%
#

# %% [markdown]
# 13. Chain two functions/methods to count the numbers of characters in `s_1` without blanks in `s_1` (do not use loops etc.!). 2 points

# %%
#

# %% [markdown]
# 14. Chain two functions/methods to count the number of words in `s_1` 2 points

# %% [markdown]
# 15. We can access list elements by a numeric index. Conversely, dictionaries allow us to access elements using a key. Write python code that creates a dictionary containing mineral names as key (e.g., Barite) and the respective chemical formula as value (e.g., BaSO4). Your dictionary should contain data for Barite, Pyrite (FeS2) and Gypsum (CaSO 4·2H2O) (3 points).

# %%
#

# %% [markdown]
# 16. Using your dictionary, write a print statement that prints the formula for barite. 1 pt

# %%
#

# %% [markdown]
# ### Advanced Questions

# %% [markdown]
# 1.  Use string methods to write code that separates the path name from the file name (including the filename extension) in variable `a = "/home/user/Downloads/my_excel_spreadsheet.xls"` Your code should have no more than three lines, including the two print statements (each on their own line). 4 points

# %%
#

# %% [markdown]
# 2.  Extend your mineral dictionary also to hold additional information, in this case, the location of the respective Wikipedia page. Modify your code in such a way that you produce the following output:
#
#     The chemical formula for
#     Barite  \
#     is  \
#     BaSO4  \
#     for more information, see  \
#     https://en.wikipedia.org/wiki/Baryte
#
# Consider how you would need to structure your dictionary to hold more than one value per key, and how you would query this information. 3 points for the correct print statements, 3 points for the correct dictionary.

# %%
#

# %% [markdown]
# 3.  in the missing python code in the first line, so that the result of the print statement in the second line yields 10 (3 points)

# %%
data = 
print(data["ESS245"]["Jen"]["Assignment 1"])

# %% [markdown]
# ### Marking

# %% [markdown]
# Two points for correct notebook name and format
#
# Total points: 43

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `A#-assignment-name-firstname-lastname`
#
# -   Where `A#` is something like A1, A2 A3, etc.
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook). This can be shortened as long as it remains clear which assignment it is.
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images, or external data, you must also copy the image and data files!
# Your notebook/pdf must start with the following lines :
#
# **ESS245: Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   Re-read the learning outcomes and verify that you are comfortable with each concept. If not, please speak up on the discussion board and ask for further clarification. I can guarantee that if you feel uncertain about a concept, at least half the class will be in the same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook format **and**
# `pdf` format:
#
# -   **Do not use File -> Save and Export as -> pdf**
# -   You **must** use your **browser's print function** (`Ctrl-P`, or `Cmd-P` on a Mac) and then select `Save as pdf`.  In the past, this worked best with Chrome or Firefox.
#
# Please submit **both files** on Quercus. Note that the pdf export can fail if your file contains invalid markup/python code. So you need to check that the pdf export is complete and does not miss any sections. If you have export problems, don't hesitate to contact the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter python code. Please use the respective cell below each question, or create a python cell where necessary. Add text cells to enter your answers where appropriate. Your responses will only count if the code executes without error. It is thus recommended to run your solutions before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by** hand. Instead, write code that produces the answer. Your pdf file\* should show the code and the results of the code execution.\*
