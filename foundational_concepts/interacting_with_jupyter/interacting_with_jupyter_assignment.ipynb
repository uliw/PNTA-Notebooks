# %% [markdown]
# ## A:2 Interacting with Jupyter

# %% [markdown]
# ### Learning Outcomes

# %% [markdown]
# -   create/delete/rename folders/files on your Jupyter cloud account
# -   create a Jupyter notebook file
# -   edit the text inside your Jupyter notebook
# -   use markdown syntax to format notebook text elements
# -   checkpoints
# -   pdf export

# %% [markdown]
# ### Instructions:

# %% [markdown]
# Enough theory! Without further ado, let's create a new notebook of your own.  Use this link to log into the Jupyter Notebook server:  [https://utoronto.syzygy.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/uliw/PNTA-Notebooks&urlpath=lab/tree/PNTA-Notebooks/foundational_concepts/interacting_with_jupyter/interacting_with_jupyter_assignment.ipynb&branch=main](https://utoronto.syzygy.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/uliw/PNTA-Notebooks&urlpath=lab/tree/PNTA-Notebooks/foundational_concepts/interacting_with_jupyter/interacting_with_jupyter_assignment.ipynb&branch=main)
#
# **Since all content in the PNTA-Notebooks folder is downloaded from** another computer (and may thus be overwritten or deleted) we must take\* **care that our notebooks are created outside the PNTA-Notebooks directory**. If you have followed the previous instructions, you will already have the `my-stuff` directory in your **root** folder. If not, please create it now.
#
# Click on this folder to enter it, and then create a new folder called `submissions`. Enter this folder, and create a new python notebook `assignment-name-firstname-lastname"` So in my case, this should look like Fig. [ref:name](ref:name)
#
# ![img](./figures/first-notebook.png "You should see the following, but make sure to use your own name")

# %% [markdown]
# #### Submission Header Information (6 pts)

# %% [markdown]
# All submissions should start with the following template
#
#     Course Title: (Level 1 heading)
#     Assignment Title:  (Level 2 heading)
#
#     Date: (bold)
#
#     First Name:  (bold)
#
#     Last Name:  (bold)
#
#     Student ID:  (bold)
#
# Add the current date, first and last name, student id, etc., in the respective places after the colon. Now change the formatting so that the text before the colon is set in bold, whereas your personal info uses a regular font. Course title as 1<sup>st</sup> level heading, Assignment Name as 2<sup>nd</sup> level heading.
#
# This should look like this
#
# ![img](./figures/header.png "Formatting example for your notebook submission")
#
# Now is a good time to save your notebook! Since all subsequent assignments will follow the same format, you can save a lot of typing by creating a copy of your notebook. Simply call it `notebook-template.ipynb`. So for the next assignment, you can simply copy the template.

# %% [markdown]
# #### Various Markdown elements (6 pts)

# %% [markdown]
# Next, go back to your notebook, and add the following elements
#
# -   a new text cell that contains a **numbered** list of your three most favored foods (1 pt)
# -   a new text cell that contains a **bullet** list of your three most favored foods (1 pt)
# -   a new text cell that contains #1 below  as a first-level (1 pt)
#     heading, #2 below as a second-level heading, the date as third level heading, and your
#     name as a fourth-level heading.
#     1.  The pleasures and tribulations of writing with markdown syntax:
#     2.  An Essay by Add your name here
#     3.  September 2022 (use current date!)
#     4.  Your Name
#
# -   A text that contains the following text as block-quote: (3 pts)
#
# > Dorothy followed her through many of the beautiful rooms in her castleUse google to find out how to do block-quotes with markdown

# %% [markdown]
# ### Marking Scheme (15 pts)

# %% [markdown]
# 1.  3 points if the filename follows the filename template (capitalization, spaces, and dashes!)
#
# 1.  12 points for the correct markdown elements.

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `A#-assignment-name-firstname-lastname`
#
# -   Where `A#` is something like A1, A2 A3, etc.
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook). This can be shortened as long as it remains clear which assignment it is.
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images, or external data, you must also copy the image and data files!
# Your notebook/pdf must start with the following lines :
#
# **ESS245: Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   Re-read the learning outcomes and verify that you are comfortable with each concept. If not, please speak up on the discussion board and ask for further clarification. I can guarantee that if you feel uncertain about a concept, at least half the class will be in the same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook format **and**
# `pdf` format:
#
# -   **Do not use File -> Save and Export as -> pdf!!!**
# -   You **must** use your **browser's print function** (`Ctrl-P`, or `Cmd-P` on a Mac) and then select `Save as pdf`.  In the past, this worked best with Chrome or Firefox.
#
# Please submit **both files** on Quercus. Note that the pdf export can fail if your file contains invalid markup/python code. So you need to check that the pdf export is complete and does not miss any sections. If you have export problems, don't hesitate to contact the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter python code. Please use the respective cell below each question, or create a python cell where necessary. Add text cells to enter your answers where appropriate. Your responses will only count if the code executes without error. It is thus recommended to run your solutions before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by** hand. Instead, write code that produces the answer. Your pdf file\* should show the code and the results of the code execution.\*
