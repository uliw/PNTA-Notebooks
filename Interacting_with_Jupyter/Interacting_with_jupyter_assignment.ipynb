# %% [markdown]
# ## Interacting with Jupyter Assignment

# %% [markdown]
# ###

# %% [markdown]
# -   add insert, copy delete, and splitting cells
# -   stopping a notebook

# %% [markdown]
# ### Learning Outcomes

# %% [markdown]
# -   create/delete/rename folders/files on your jupyter cloud account
# -   create a jupyter notebook file
# -   edit the text inside your jupyter notebook
# -   use markdown syntax to format notebook text elements
# -   start stop server
# -   shutdown notebook
# -   checkpoints
# -   pdf export

# %% [markdown]
# ### Instructions:

# %% [markdown]
# Enough theory! Without further ado, let's create a new notebook of
# your own.  Use this link to log into the Jupyter Notebook server:
#
# [https://utoronto.syzygy.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/uliw/PNTA-Notebooks&urlpath=lab/tree/PNTA-Notebooks/Interacting_with_Jupyter/Interacting_with_jupyter-2.ipynb&branch=main](https://utoronto.syzygy.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/uliw/PNTA-Notebooks&urlpath=lab/tree/PNTA-Notebooks/Interacting_with_Jupyter/Interacting_with_jupyter-2.ipynb&branch=main)
#
# **Since all content in the PNTA-Notebooks folder is downloaded from**
# **another computer (and may thus be overwritten or deleted) we must
# take** **care that our notebooks are created outside the PNTA-Notebooks
# directory**.  If you have followed the previous instructions, you will
# already have the `my-stuff` directory in your **root** folder. If not,
# please create it now.
#
# Click on this folder to enter it, and then create a new folder called
#  `my-pnta-notebooks-submissions`. Enter this folder, and create a
#  new python notebook `assignment-name-firstname-lastname"`
# So in my case, this should look like Fig. [name](name)
#
# ![img](./figures/first-notebook.png "You should see the following, but make sure to use your own name")
#
# In the middle of the menu bar, you will see the word `Code` just right
# of the double right arrow. This box tells you that the first (and
# currently empty cell) is a code box. You can change the cell type to
# `Markdown` by left-clicking on `Code`, or by using the `Cell` menu.
#
# 1.  Go ahead and change it to "Markdown".
# 2.  Now add the following text to this cell: "ESS245 Computational Geology Text Edit Assignment"
# 3.  Save your edits by hitting `shift+enter`
# 4.  Select this cell again (double left click) and now modify the text
#     using markdown syntax in such a way that it becomes a level 1
#     heading (see above).
# 5.  Now is a good time ti hist the disk icon in your edit window. This will create a checkpoint. Checkpoints can be used to return to a previous version. As you experiment with code, it is good idea to create checkpoints frequently (typically whenever something works, and before you try a new experiment).
#
# If you already have a new cell below the heading, change it to
# markdown mode (see above), or insert a new cell
# (`Insert -> Cell below`) and change it to markdown afterward.
#
# In this cell, add the following text
#
#     Course Title:
#     Assignment Title:
#
#     Date:
#
#     First Name:
#
#     Last Name:
#
#     Student ID:
#
# Add the current date, first and last name, student id, etc., in the respective places
# after the colon. Now change the formatting so that the text
# before the colon is set in bold, whereas your personal info uses
# a regular font. Course title as 1<sup>st</sup>  level heading, Assignment Name as 2<sup>nd</sup> level heading.
#
# This should look like this
#
# ![img](./figures/Screenshot_20200921_111320.png "Formatting example for your notebook submission")
#
# Now is a good time to save your notebook! Since all
# subsequent assignments will follow the same format, you can save
# a lot of typing by creating a copy of your notebook. Simply
# call it `notebook-template.ipynb`. So for the next assignment, you can
# simply copy the template.
#
# Next, go back to your notebook, and add the following elements
#
# -   a new text cell that contains a numbered list of your three most favored foods
# -   a new text cell that contains a bullet list of your three most favored foods
# -   a new text cell that contains #1 below  as a first-level
#     heading, #2 below as a second-level heading, the date as third level heading, and your
#     name as a fourth-level heading.
#     1.  The pleasures and tribulations of writing with markdown syntax:
#     2.  An Essay by Add your name here
#     3.  September 2022
#     4.  Your Name
#
# -   A text that contains the following text as blockquote:
#
# Dorothy followed her through many of the beautiful rooms in her castle.
#
# Use google to find out how to do blockquotes with markdown

# %% [markdown]
# ### Marking Scheme

# %% [markdown]
# 1.  3 points if the filename follows the filename template (capitalization, spaces, and dashes!)
# 2.  2 points per text cell if your text content is as requested (one for content, one
#     for layout) (5 \* 2) = 10

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy `assignment-name-firstname-lastname"`
#
# -   Replace the `assignment-name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook)
# -   `firstname-lastname` with your own name.
#
# Note: If the notebook contains images, you must also copy the image files!
#
# Your notebook/pdf must start with the following lines
#
# **Course Title:**
#
# **Assignment Title:**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   re-read the learning outcomes and verify that you are comfortable
#     with each concept. If not, please speak up on the discussion board
#     and ask for further clarification. I can guarantee that if you feel
#     uncertain about a concept, at least half the class will be in the
#     same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook
# format **and** `pdf` format. **To export your notebook as pdf
# use your browser's print function (`Ctrl-P`) and then select**
# `Save as pfd`.  Please submit **both files** on Quercus. Note that the pdf
# export can fail if your file contains invalid markup/python code. So
# you need to check that the pdf export is complete and does not miss
# any sections. If you have export problems, don't hesitate to contact
# the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter
# python code. Please use the respective cell below each question, or
# create a python cell where necessary. Add text cells to enter your
# answers where appropriate. Your responses will only count if the code
# executes without error. It is thus recommended to run your solutions
# before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by**
# **hand. Instead, write code that produces the answer. Your pdf file**
# **should show the code and the results of the code execution.**
