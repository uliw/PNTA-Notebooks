# %% [markdown]
# ESS245
# ======
#
# **Author:** Ulrich G Wortmann

# %% [markdown]
# ## Recap Functions

# %% [markdown]
# ### Beware of lists in loops and functions

# %%
my_list = [1, 2, 3]
for e in my_list:
    my_list.append(e)

# %% [markdown]
# ### Make your own enumerate

# %%
def my_enum(ml):
   
    result = ()
    for i in range(len(ml)):
        result = result + ((i, ml[i]),)
    return result

# %% [markdown]
# ### Improve readability with a docstring

# %%
def my_enum(ml):
    """Return a list of tuples where each tuple contains the index and value
    for each element in ml.
    """
    result = ()
    for i in range(len(ml)):
        result = result + ((i, ml[i]),)
    return result

# %% [markdown]
# ### Do things step-wise!

# %%
extract_table_headers_as_list()
get_dict_entry_as_list()
add_table_seperators()
make_list_entries_bold()

# %%
# testcase for extract_table_headers_as_list()

# %%
# testcase for get_dict_entry_as_list()

# %%
# testcase for add_table_seperators()

# %% [markdown]
# ## Today

# %% [markdown]
# ### Better docstrings

# %%
def my_enum(ml):
    """ my_enum expects a list and will return a list of tuples, where
    each tuple contains the index position and value of the list elements.

    Parameters:
    -----------
    ml : list
        any list-type object

    Returns:
    --------
    result
        a tuple of tuples ((index, value), ....)

    Examples:
    ---------
        a = ["a", "B"]
        print(my_enum(a))
        returns ((0,"a"),(1,"b"))
    """
    result = ()
    for i in range(len(ml)):
        result = result + ((i, ml[i]),)
    return result

# %% [markdown]
# ### Type hints

# %%
def my_enum(ml: list[Any]) -> tuple[tuple[int, Any]]:
    """ my_enum expects a list and will return a list of tuples, where
    each tuple contains the index position and value of the list elements.
    
    Parameters:
    -----------
    ml : list
        any list-type object

    Returns:
    --------
    result
        a tuple of tuples ((index, value), ....)

    Examples:
    ---------
        a = ["a", "B"]
        print(my_enum(a))
        returns ((0,"a"),(1,"b"))
    """
