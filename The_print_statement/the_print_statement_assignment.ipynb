# %% [markdown]
# ## Assignment

# %% [markdown]
# All questions should be solved with the techniques introduced in the
# tutorial. As usual, copy this notebook, add your header, and split the book below each question.

# %% [markdown]
# ### Learning Outcomes

# %% [markdown]
# -   Become familiar with f-strings
# -   Become comfortable using escape sequences
# -   Become familiar with format modifiers
# -   Practice formatted screen output

# %% [markdown]
# ### Tasks

# %% [markdown]
# -   Set a = to 12 and then write a python statement in such a way that
#     you get the following output (1pt).
#
#         The value of the variable a = 12
#
#     Note I don't want you to type a string with these words. Use an
#      f-string and use the appropriate syntax so that the actual value of
#      `a` is printed.
#
# -   Using the same code as above and include escape sequences in such a
#     way that your printout is preceded and followed by an empty line
#     (1pt).
#
# -   Using the same code as in 2, precede and follow the empty lines
#     with 41 dashes (see below). Note that rather than typing (and
#     counting), use this statement `'-' * 41`. Your result should look like
#     this - including the empty lines. (1pt).
#
#         ----------------------------------------
#
#         The value of the variable a = 12
#
#         ----------------------------------------
#
# -   Modify the first and last print statement  in such a
#     way that you get the output below (1pt)
#
#         *----------------------------------------*
#
#         The value of the variable a = 12
#
#         *----------------------------------------*
#
# -   Using the above code, add an escape sequence in front of "The
#     value&#x2026;" to display the text shifted by one tab to the
#     right. (1pt)
#
# -   You are working on software for a point of sale system (i.e., cash
#     register). Your software knows the sales price and
#     how much cash you receive from the customer. Write some python
#     code that calculates and displays the change owed. Your display
#     should look like this (your number may be different!):
#
#         Change owed = $12.40
#
#     Notes: A) You code should correctly round the owed amount to the
#     nearest 10 cents and display the cents as in the above example; B)
#     You should achieve this by using the appropriate format modifier
#     and by making good use of the f-string. Assume that the customer
#     provided you with a twenty-dollar bill and that the item's price
#     was CAD 6.63. Also, test your code with a price of $6.67. (4pts)
#
# -   Using the example in #6, print a proper receipt rather than
#     printing the change owed. Towards this end, add a variable that
#     describes the item. Your output should look like this (note that
#     the point separating the cents from the dollars must be aligned)

# %%
"""
Cheese        $6.63
HST           $
-------------------
Total         $

Paid          $
Change owed = $
"""

# %% [markdown]
# Notes: This is meant to be an actual program. In other words, your
# code should be universal. So we do not want to write

# %%
print(f"Cheese \t \t $6.63")

# %% [markdown]
# rather, we want to declare each value in a variable like this

# %%
item_name = "Cheese"
cost = 2.63  # in dollars
hst = 13  # as percent
paid = 20  # dollars

# %% [markdown]
# and then use those variables in our code. The advantage is that  if
#    you want to change your price or item name, you change the
#    variable definition at the beginning of the code, rather than
#    having to modify the internals of your code.
#
# Notes:
#
# -   you first need to calculate the HST (13%)
# -   Do not forget to do the rounding and make sure that  `total` plus `changed_owed` are equal to `paid`. In other words, be  on the lookout for rounding errors.
#
# -   The dollar sign of the price should be three tab stops to the right. The length of the item description should    be limited so that it won't displace the price. Test  this by setting `item = "Really Long Pasta"` (5pts)
#
# -   Avoid long and complex print statements. Rather, use a new print statement for each line. Coding is the art of avoiding complexity.
#
# Total Points: 14

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# Create a new (or copy and existing) notebook in your `submissions`
# folder before editing it. Otherwise, your edits may be overwritten the
# next time you log into syzygy. Please name your copy
# "Assignment-Name-FirstName-LastName":
#
# -   Replace the `Assignment-Name` with the name of the assignment
#     (i.e., the filename of the respective Jupyter Notebook)
# -   `FirstName-Last-Name` with your own name.
#
# Note: If the notebook contains images, you must also copy the image files!
#
# Your notebook/pdf must start with the following lines
#
# **Assignment Title**
#
# **Date:**
#
# **First Name:**
#
# **Last Name:**
#
# **Student: Id**
#
# Before submitting your assignment:
#
# -   Check the marking scheme and ensure you have covered all requirements.
# -   re-read the learning outcomes and verify that you are comfortable
#     with each concept. If not, please speak up on the discussion board
#     and ask for further clarification. I can guarantee that if you feel
#     uncertain about a concept, at least half the class will be in the
#     same boat. So don't be shy!
#
# To submit your assignment, you need to download it as `ipynb` notebook
# format **and** `pdf` format. The best way to export your notebook as pdf
# is to use your browser's print function (`Ctrl-P`) and then select
# `Save as pfd`.  Please submit both files on Quercus. Note that the pdf
# export can fail if your file contains invalid markup/python code. So
# you need to check that the pdf export is complete and does not miss
# any sections. If you have export problems, don't hesitate to contact
# the course instructor directly.
#
# Notebooks typically have empty code cells in which you must enter
# python code. Please use the respective cell below each question, or
# create a python cell where necessary. Add text cells to enter your
# answers where appropriate. Your responses will only count if the code
# executes without error. It is thus recommended to run your solutions
# before submitting the assignment.
#
# **Note: Unless specifically requested, do not type your answers by**
# **hand. Instead, write code that produces the answer. Your pdf file**
# **should show the code and the results of the code execution.**
