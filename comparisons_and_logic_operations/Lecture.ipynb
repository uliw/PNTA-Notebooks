# %% [markdown]
# Comparison and Logic Operators
# ==============================
#
# **Author:** Ulrich G Wortmann

# %% [markdown]
# ## Recap

# %% [markdown]
# ### fstrings

# %% [markdown]
#     ms = f"10 / 3 = {10 / 3}"
#     print(ms)
#
#     10 / 3 = 3.3333333333333335

# %% [markdown]
# ### format modifiers

# %% [markdown]
#     ms = f"10 / 3 = {10 / 3:0>8.2f}"
#     print(ms)

# %% [markdown]
# ## Comparisons

# %% [markdown]
# ### Greater and smaller

# %% [markdown]
#     print(12 > 2)
#     print(12 < 2)

# %% [markdown]
# ### The trouble with equal

# %% [markdown]
#     print(12 = 12)
#
#
#     print(12 == 12)
#
# :END:

# %% [markdown]
# ### unequal

# %% [markdown]
#     print(12 != 12)

# %% [markdown]
# ### strings

# %% [markdown]
#     print("aaa" <  "uu")

# %% [markdown]
# ### Truth values

# %% [markdown]
#     print(True == 1)

# %% [markdown]
# ## Logic Operators

# %% [markdown]
# ### And/Or

# %% [markdown]
#     print(False or not False)

# %% [markdown]
# ### Logical or (xor)

# %% [markdown]
# also **exclusive or**, i.e., only one of the conditions can be true
# Consider the regular **or** :
#
#     print(f"False or False = {False or False}")
#     print(f"False or True = {False or True}")
#     print(f"True or True = {True or True}")
#
#     False or False = False
#     False or True = True
#     True or True = True
#
# and now the exclusive or, called **xor**, or in python syntax `a ^ b`
#
#     print(f"False xor False = {False ^ False}")
#     print(f"False xor True = {False ^ True}")
#     print(f"True xor True = {True ^ True}")
#
#     False xor False = False
#     False xor True = True
#     True xor True = False

# %% [markdown]
# ### Invert (also Not)

# %% [markdown]
#     a = True
#     print(not a)
#
#     False

# %% [markdown]
# ## BTW, why are these important?

# %% [markdown]
# -   you now can make decisions in your code!
# -   logical operators can be build in silicon with transistors
# -   you know xor from your daily live
# -   they are in fact the base of most computing operations
# -   not sure if these examples are correct, but they show the principle ;-)

# %% [markdown]
# ### Addition

# %% [markdown]
#     # always start on the right moving to the left
#       0101 # = 5
#     + 0010 # = 2
#     ------------
#       0111 # = 7 -> xor allows binary addition
#       0000 # and
#
#     # example with carry over
#       0101 # = 5
#     + 0101 # = 5
#     ------------
#       0000 # xor
#       1010 # and - but 1 + 1 needs a the carry over bit
#       1010 = 10

# %% [markdown]
# ### Subtraction

# %% [markdown]
#     # always start on the right moving to the left
#       0101 # = 5
#     - 0010 # = 2
#     ------------
#
#     1) Invert the number 2 by flipping bits
#        0010 = 2
#     -> 0001 = 2 inverted
#
#     2) add one bit to the right
#        0001
#        0001 + 1 consider carry over if necssary
#     -> 0010
#
#     3) add both numbers with xor, ignoring the left most bit
#        0101 = 5
#     +  0010 = 2
#     -----------
#     -> 0011 = 3
